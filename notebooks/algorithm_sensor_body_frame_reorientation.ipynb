# %%
import matplotlib.pyplot as plt
from load import load_2023_12_30
from tile import Tile
from track import Track
from signal_processing import maxIndex

a50_2023_12_30, a50_all_2023_12_30, f6p_2023_12_30, tile_2023_12_30_runs = load_2023_12_30()
# Out:
# A50 Downhill Tracks
# 	 Track type Downhill | Date 2023-12-30 | Time 12:06:29 | Duration [s] 115 | Length [m] 977
# 	 Track type Downhill | Date 2023-12-30 | Time 12:18:53 | Duration [s] 114 | Length [m] 1032
# 	 Track type Downhill | Date 2023-12-30 | Time 12:21:47 | Duration [s] 40 | Length [m] 111
# A50 All Tracks
# 	 Track type Hold | Date 2023-12-30 | Time 11:52:15 | Duration [s] 110 | Length [m] 36
# 	 Track type Walk | Date 2023-12-30 | Time 11:54:05 | Duration [s] 103 | Length [m] 56
# 	 Track type Hold | Date 2023-12-30 | Time 11:55:48 | Duration [s] 74 | Length [m] 22
# 	 Track type Walk | Date 2023-12-30 | Time 11:57:02 | Duration [s] 82 | Length [m] 53
# 	 Track type Lift | Date 2023-12-30 | Time 11:58:24 | Duration [s] 485 | Length [m] 862
# 	 Track type Downhill | Date 2023-12-30 | Time 12:06:29 | Duration [s] 115 | Length [m] 977
# 	 Track type Walk | Date 2023-12-30 | Time 12:08:24 | Duration [s] 92 | Length [m] 75
# 	 Track type Lift | Date 2023-12-30 | Time 12:09:56 | Duration [s] 410 | Length [m] 814
# 	 Track type Hold | Date 2023-12-30 | Time 12:16:46 | Duration [s] 127 | Length [m] 17
# 	 Track type Downhill | Date 2023-12-30 | Time 12:18:53 | Duration [s] 114 | Length [m] 1032
# 	 Track type Hold | Date 2023-12-30 | Time 12:20:47 | Duration [s] 60 | Length [m] 15
# 	 Track type Downhill | Date 2023-12-30 | Time 12:21:47 | Duration [s] 40 | Length [m] 111
# 	 Track type Walk | Date 2023-12-30 | Time 12:22:27 | Duration [s] 70 | Length [m] 65
# F6P Tracks
# 	 Track type Downhill | Date 2023-12-30 | Time 12:06:15 | Duration [s] 106 | Length [m] 955.88
# 	 Track type Downhill | Date 2023-12-30 | Time 12:16:45 | Duration [s] 126 | Length [m] 1023.52
# 	 Track type Downhill | Date 2023-12-30 | Time 12:30:55 | Duration [s] 134 | Length [m] 1083.94
# 	 Track type Downhill | Date 2023-12-30 | Time 12:40:23 | Duration [s] 105 | Length [m] 1008.92
# 	 Track type Downhill | Date 2023-12-30 | Time 12:53:28 | Duration [s] 106 | Length [m] 1018.07
# 	 Track type Downhill | Date 2023-12-30 | Time 13:05:24 | Duration [s] 111 | Length [m] 1033.85
# 	 Track type Downhill | Date 2023-12-30 | Time 13:14:27 | Duration [s] 108 | Length [m] 1017.04
# 	 Track type Downhill | Date 2023-12-30 | Time 13:23:32 | Duration [s] 121 | Length [m] 992.7
# 	 Track type Downhill | Date 2023-12-30 | Time 13:35:22 | Duration [s] 117 | Length [m] 1027.84
# 	 Track type Downhill | Date 2023-12-30 | Time 13:45:46 | Duration [s] 109 | Length [m] 1026.8
# 	 Track type Downhill | Date 2023-12-30 | Time 13:55:49 | Duration [s] 106 | Length [m] 1035.32
# 	 Track type Downhill | Date 2023-12-30 | Time 14:05:34 | Duration [s] 114 | Length [m] 1043.99
# 	 Track type Downhill | Date 2023-12-30 | Time 14:14:43 | Duration [s] 115 | Length [m] 1023.95
# 	 Track type Downhill | Date 2023-12-30 | Time 14:23:51 | Duration [s] 124 | Length [m] 1044.96
# 	 Track type Downhill | Date 2023-12-30 | Time 14:32:54 | Duration [s] 103 | Length [m] 1015.87
# 	 Track type Downhill | Date 2023-12-30 | Time 14:41:49 | Duration [s] 116 | Length [m] 1026.54
# 	 Track type Downhill | Date 2023-12-30 | Time 14:51:06 | Duration [s] 122 | Length [m] 1087.56
# 	 Track type Downhill | Date 2023-12-30 | Time 15:13:56 | Duration [s] 91 | Length [m] 847.66
# 	 Track type Downhill | Date 2023-12-30 | Time 15:22:30 | Duration [s] 88 | Length [m] 855.89
# 	 Track type Downhill | Date 2023-12-30 | Time 15:39:19 | Duration [s] 207 | Length [m] 1003.7
# 	 Track type Downhill | Date 2023-12-30 | Time 15:54:25 | Duration [s] 84 | Length [m] 841.87
# 	 Track type Downhill | Date 2023-12-30 | Time 16:04:38 | Duration [s] 94 | Length [m] 815.66
# Tile Full Recording
# self.quat.shape: (197547, 4)
# self.quat.shape: (197547, 4)
# 	 Duration [s] 1975
# Synchronized Tile Parameters
# 	Timestamp offset: 8000
# 	Altitude offset: 132.0
# Tile Split into Downhill Tracks
# self.quat.shape: (11500, 4)
# self.quat.shape: (11500, 4)
# self.quat.shape: (11400, 4)
# self.quat.shape: (11400, 4)
# self.quat.shape: (4000, 4)
# self.quat.shape: (4000, 4)
# 	 Track type Downhill | Date 2023-12-30 | Time 12:06:29 | Duration [s] 115 | Length [m] 977
# 	 Track type Downhill | Date 2023-12-30 | Time 12:18:53 | Duration [s] 114 | Length [m] 1032
# 	 Track type Downhill | Date 2023-12-30 | Time 12:21:47 | Duration [s] 40 | Length [m] 111

# %% [markdown]
# ## Plotting Euler Data with G-forces
#
# G-forces should register at twice the frequency due to similar angular accelerations felt at every turn, while rolling should occur +ve, then -ve between turns. Assuming this, we can clearly calculate the number of turns and determine if they were left or right.

# %%
run1 = tile_2023_12_30_runs[0]
run2 = tile_2023_12_30_runs[1]
run1_euler6 = run1.imu6.euler
run1_euler9 = run1.imu9.euler
run2_euler6 = run2.imu6.euler
run2_euler9 = run2.imu9.euler

print(run1.imu6.quat.shape)
print(run1.imu6.euler.shape)
# Out:
# (11500, 4)
# (11500, 3)

# %%
plt.rc('lines', linewidth=1)
fig, ax = plt.subplots(5, figsize=(15, 8))

ax[0].plot(run1.time, run1_euler6[:, 0], label='6dof')
ax[0].plot(run1.time, run1_euler9[:, 0], label='9dof')
ax[0].set_title('Run 1 Roll', wrap=True)
ax[0].legend()

ax[1].plot(run1.time, run1_euler6[:, 1], label='6dof')
ax[1].plot(run1.time, run1_euler9[:, 1], label='9dof')
ax[1].set_title('Run 1 Pitch', wrap=True)
ax[1].legend()

ax[2].plot(run1.time, run1_euler6[:, 2], label='6dof')
ax[2].plot(run1.time, run1_euler9[:, 2], label='9dof')
ax[2].set_title('Run 1 Yaw', wrap=True)
ax[2].legend()

ax[3].plot(run1.time, run1.mG_lpf())
ax[3].set_title('Run 1 Filtered mG-forces', wrap=True)

ax[4].plot(run1.time, run1.mG)
ax[4].set_title('Run 1 Unfiltered mG-forces', wrap=True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Identifying the Still Points
#
# Maintain a causal design!

# %%
_, _, _, tile_2023_12_30 = load_2023_12_30(split_tile=False)
tile_2023_12_30_euler6 = tile_2023_12_30.imu6.euler
tile_2023_12_30_euler9 = tile_2023_12_30.imu9.euler
# Out:
# A50 Downhill Tracks
# 	 Track type Downhill | Date 2023-12-30 | Time 12:06:29 | Duration [s] 115 | Length [m] 977
# 	 Track type Downhill | Date 2023-12-30 | Time 12:18:53 | Duration [s] 114 | Length [m] 1032
# 	 Track type Downhill | Date 2023-12-30 | Time 12:21:47 | Duration [s] 40 | Length [m] 111
# A50 All Tracks
# 	 Track type Hold | Date 2023-12-30 | Time 11:52:15 | Duration [s] 110 | Length [m] 36
# 	 Track type Walk | Date 2023-12-30 | Time 11:54:05 | Duration [s] 103 | Length [m] 56
# 	 Track type Hold | Date 2023-12-30 | Time 11:55:48 | Duration [s] 74 | Length [m] 22
# 	 Track type Walk | Date 2023-12-30 | Time 11:57:02 | Duration [s] 82 | Length [m] 53
# 	 Track type Lift | Date 2023-12-30 | Time 11:58:24 | Duration [s] 485 | Length [m] 862
# 	 Track type Downhill | Date 2023-12-30 | Time 12:06:29 | Duration [s] 115 | Length [m] 977
# 	 Track type Walk | Date 2023-12-30 | Time 12:08:24 | Duration [s] 92 | Length [m] 75
# 	 Track type Lift | Date 2023-12-30 | Time 12:09:56 | Duration [s] 410 | Length [m] 814
# 	 Track type Hold | Date 2023-12-30 | Time 12:16:46 | Duration [s] 127 | Length [m] 17
# 	 Track type Downhill | Date 2023-12-30 | Time 12:18:53 | Duration [s] 114 | Length [m] 1032
# 	 Track type Hold | Date 2023-12-30 | Time 12:20:47 | Duration [s] 60 | Length [m] 15
# 	 Track type Downhill | Date 2023-12-30 | Time 12:21:47 | Duration [s] 40 | Length [m] 111
# 	 Track type Walk | Date 2023-12-30 | Time 12:22:27 | Duration [s] 70 | Length [m] 65
# F6P Tracks
# 	 Track type Downhill | Date 2023-12-30 | Time 12:06:15 | Duration [s] 106 | Length [m] 955.88
# 	 Track type Downhill | Date 2023-12-30 | Time 12:16:45 | Duration [s] 126 | Length [m] 1023.52
# 	 Track type Downhill | Date 2023-12-30 | Time 12:30:55 | Duration [s] 134 | Length [m] 1083.94
# 	 Track type Downhill | Date 2023-12-30 | Time 12:40:23 | Duration [s] 105 | Length [m] 1008.92
# 	 Track type Downhill | Date 2023-12-30 | Time 12:53:28 | Duration [s] 106 | Length [m] 1018.07
# 	 Track type Downhill | Date 2023-12-30 | Time 13:05:24 | Duration [s] 111 | Length [m] 1033.85
# 	 Track type Downhill | Date 2023-12-30 | Time 13:14:27 | Duration [s] 108 | Length [m] 1017.04
# 	 Track type Downhill | Date 2023-12-30 | Time 13:23:32 | Duration [s] 121 | Length [m] 992.7
# 	 Track type Downhill | Date 2023-12-30 | Time 13:35:22 | Duration [s] 117 | Length [m] 1027.84
# 	 Track type Downhill | Date 2023-12-30 | Time 13:45:46 | Duration [s] 109 | Length [m] 1026.8
# 	 Track type Downhill | Date 2023-12-30 | Time 13:55:49 | Duration [s] 106 | Length [m] 1035.32
# 	 Track type Downhill | Date 2023-12-30 | Time 14:05:34 | Duration [s] 114 | Length [m] 1043.99
# 	 Track type Downhill | Date 2023-12-30 | Time 14:14:43 | Duration [s] 115 | Length [m] 1023.95
# 	 Track type Downhill | Date 2023-12-30 | Time 14:23:51 | Duration [s] 124 | Length [m] 1044.96
# 	 Track type Downhill | Date 2023-12-30 | Time 14:32:54 | Duration [s] 103 | Length [m] 1015.87
# 	 Track type Downhill | Date 2023-12-30 | Time 14:41:49 | Duration [s] 116 | Length [m] 1026.54
# 	 Track type Downhill | Date 2023-12-30 | Time 14:51:06 | Duration [s] 122 | Length [m] 1087.56
# 	 Track type Downhill | Date 2023-12-30 | Time 15:13:56 | Duration [s] 91 | Length [m] 847.66
# 	 Track type Downhill | Date 2023-12-30 | Time 15:22:30 | Duration [s] 88 | Length [m] 855.89
# 	 Track type Downhill | Date 2023-12-30 | Time 15:39:19 | Duration [s] 207 | Length [m] 1003.7
# 	 Track type Downhill | Date 2023-12-30 | Time 15:54:25 | Duration [s] 84 | Length [m] 841.87
# 	 Track type Downhill | Date 2023-12-30 | Time 16:04:38 | Duration [s] 94 | Length [m] 815.66
# Tile Full Recording
# self.quat.shape: (197547, 4)
# self.quat.shape: (197547, 4)
# 	 Duration [s] 1975
# Synchronized Tile Parameters
# 	Timestamp offset: 8000
# 	Altitude offset: 132.0

# %%
a50_lifts = [track for track in a50_all_2023_12_30 if track.track_type == "Lift"]

# %% [markdown]
# ### Reprenting Lift and Ski Zones

# %%
def addRunAndLiftZones(ax, runs, lifts):
    [ax.axvspan(run.time[0], run.time[-1], color='green', alpha=0.25) for run in runs]
    [ax.axvspan(lift.time[0], lift.time[-1], color='red', alpha=0.25) for lift in lifts]

# %%
plt.rc('lines', linewidth=1)
fig, ax = plt.subplots(5, figsize=(15, 8))

ax[0].plot(tile_2023_12_30.time, tile_2023_12_30_euler6[:, 0], label='6dof')
ax[0].plot(tile_2023_12_30.time, tile_2023_12_30_euler9[:, 0], label='9dof')
addRunAndLiftZones(ax[0], tile_2023_12_30_runs, a50_lifts)
ax[0].set_title('All Tile Roll with Run & Lift Zones', wrap=True)
ax[0].legend()

ax[1].plot(tile_2023_12_30.time, tile_2023_12_30_euler6[:, 1], label='6dof')
ax[1].plot(tile_2023_12_30.time, tile_2023_12_30_euler9[:, 1], label='9dof')
addRunAndLiftZones(ax[1], tile_2023_12_30_runs, a50_lifts)
ax[1].set_title('All Tile Pitch with Run & Lift Zones', wrap=True)
ax[1].legend()

ax[2].plot(tile_2023_12_30.time, tile_2023_12_30_euler6[:, 2], label='6dof')
ax[2].plot(tile_2023_12_30.time, tile_2023_12_30_euler9[:, 2], label='9dof')
addRunAndLiftZones(ax[2], tile_2023_12_30_runs, a50_lifts)
ax[2].set_title('All Tile Yaw with Run & Lift Zones', wrap=True)
ax[2].legend()

ax[3].plot(tile_2023_12_30.time, tile_2023_12_30.mG_lpf())
addRunAndLiftZones(ax[3], tile_2023_12_30_runs, a50_lifts)
ax[3].set_title('All Tile Filtered mG-forces with Run & Lift Zones', wrap=True)

ax[4].plot(tile_2023_12_30.time, tile_2023_12_30.mG)
addRunAndLiftZones(ax[4], tile_2023_12_30_runs, a50_lifts)
ax[4].set_title('All Tile Unfiltered mG-forces with Run & Lift Zones', wrap=True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### At the Point of Lift Liftoff
#
# Taking a closer look at the start of the lift zone, starting with the first lift:

# %%
start = tile_2023_12_30.time.index(a50_lifts[0].time[0])
x1 = start - 2500 # sub time to window
x2 = start + 2500 # add time to window
print(x1, x2)
# Out:
# 42400 47400

# %%
impact_idx = maxIndex(tile_2023_12_30.mG, [x1, x2])

# %%
def plotEulerAndGs(x1, x2):
    plt.rc('lines', linewidth=1)
    fig, ax = plt.subplots(6, figsize=(14, 9))

    ax[0].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30.corrected_alt[x1:x2], label='tile')
    ax[0].axvline(x=tile_2023_12_30.time[impact_idx], color='k')
    ax[0].set_title('Moment of Lift 1 Liftoff Tile Altitude (Correced from A50)', wrap=True)
    ax[0].legend()

    ax[1].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30_euler6[x1:x2, 0], label='6dof')
    ax[1].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30_euler9[x1:x2, 0], label='9dof')
    ax[1].axvline(x=tile_2023_12_30.time[impact_idx], color='k')
    ax[1].set_title('Moment of Lift 1 Liftoff Tile Roll', wrap=True)
    ax[1].legend()

    ax[2].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30_euler6[x1:x2, 1], label='6dof')
    ax[2].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30_euler9[x1:x2, 1], label='9dof')
    ax[2].axvline(x=tile_2023_12_30.time[impact_idx], color='k')
    ax[2].set_title('Moment of Lift 1 Liftoff Tile Pitch', wrap=True)
    ax[2].legend()

    ax[3].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30_euler6[x1:x2, 2], label='6dof')
    ax[3].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30_euler9[x1:x2, 2], label='9dof')
    ax[3].axvline(x=tile_2023_12_30.time[impact_idx], color='k')
    ax[3].set_title('Moment of Lift 1 Liftoff Tile Yaw', wrap=True)
    ax[3].legend()

    ax[4].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30.mG_lpf()[x1:x2])
    ax[4].axvline(x=tile_2023_12_30.time[impact_idx], color='k')
    ax[4].set_title('Moment of Lift 1 Liftoff Tile Filtered mG-forces', wrap=True)

    ax[5].plot(tile_2023_12_30.time[x1:x2], tile_2023_12_30.mG[x1:x2])
    ax[5].axvline(x=tile_2023_12_30.time[impact_idx], color='k')
    ax[5].set_title('Moment of Lift 1 Liftoff Tile Unfiltered mG-forces', wrap=True)

    plt.tight_layout()
    plt.show()

# %%
plotEulerAndGs(x1, x2)

# %% [markdown]
# #### Analysis
#
# - the first flat period is waiting in line for the gate to open, not always available
# - the second is standing waiting for the lift to hit the legs, seen by the impulse in the unfiltered mG-forces
#   - motion during this time may happen, only correct for times it doesn't since this will always happen

# %% [markdown]
# ### At the Point of Lift Landing
#
# Taking a closer look at the end of the lift zone, starting with the first lift:

# %%
stop = tile_2023_12_30.time.index(a50_lifts[0].time[-1])
x1 = stop - 2500 # sub time to window
x2 = stop + 2500 # add time to window
print(x1, x2)
impact_idx = maxIndex(tile_2023_12_30.mG, [x1, x2])
plotEulerAndGs(x1, x2)
# Out:
# 90900 95900

# %% [markdown]
# #### Analysis
#
# - the main flat period is seen as the point where the chair is pushing you while your skis are flat on the platform
# - results in a pretty good steady state for all signals!

# %% [markdown]
# #### Confirming this Occurs on the Next Chair Landing

# %%
stop = tile_2023_12_30.time.index(a50_lifts[1].time[-1])
x1 = stop - 2500 # sub time to window
x2 = stop + 2500 # add time to window
print(x1, x2)
impact_idx = maxIndex(tile_2023_12_30.mG, [x1, x2])
plotEulerAndGs(x1, x2)
# Out:
# 152600 157600

# %% [markdown]
# ## Identification Steps
#
# ### v1
#
# 0. must first be in lift state, identified by constant acc (& vel), and increasing altitude
# 1. triggered by altitude & when it begins decreasing from its max
# 2. search all signals in +t until a medium window has a low enough std dev
# 3. confirm an impact in the unfiltered mG was observed, to isolate the cases where the chair stopped
# 4. confirm altitude never increses, otherwise break
# 5. capture signals during a small window of low std dev, stretching to the length of time SS is observed

# %%
from numpy import std
# from signal_processing import std

def testMotionForStillness(tile: Tile, r):
    # alt_lpf_std_th = 3
    # roll_std_th = 5
    # pitch_std_th = 5
    # yaw_std_th = 5
    euler_std_th = 3
    # mG_lpf_std_th = 25
    mG_std_th = 50
    return [
        # std(tile.corrected_alt[r[0]:r[1]]) < alt_lpf_std_th,
        # std(tile_euler9[r[0]:r[1], 0]) < roll_std_th,
        # std(tile_euler9[r[0]:r[1], 1]) < pitch_std_th,
        # std(tile_euler9[r[0]:r[1], 2]) < yaw_std_th,
        std(tile.imu9.euler_norm[r[0]:r[1]]) < euler_std_th,
        # std(tile.mG_lpf()[r[0]:r[1]]) < mG_lpf_std_th,
        std(tile.mG[r[0]:r[1]]) < mG_std_th,
    ]

# %%
def identifyStillRanges(tile: Tile, min_s=6, r=[0, -1], print_out=False):
    """Identifies ranges of still motion with sampling length `min_s` in seconds
    and returns them as a list of lists representing their indices.
    """
    wsamples = min_s * 100
    search = (len(tile.time[r[0]:r[1]])) - wsamples
    coarse_mult = wsamples
    fine_mult = round(coarse_mult / 10)
    still_ranges = []
    prev_tail = r[0]
    print('search:', search)
    print('coarse_mult:', coarse_mult)
    print('fine_mult:', fine_mult)

    for i in range(search):
        if print_out: print('i iter:\t', i)
        for j in range(search):
            # coarse search every 10th idx
            head = prev_tail + coarse_mult * j
            tail = head + wsamples
            
            if tail >= search + r[0]:
                if print_out: print('hit the end of the line. tail >= search:', tail, '>=', search + r[0])
                return still_ranges
            
            trailing_tests = testMotionForStillness(tile, [head, tail])

            if print_out: print('j iter:\t', j)
            if print_out: print('head = prev_tail + coarse_mult * j:\t', head, '=', prev_tail, '+', coarse_mult * j)
            if print_out: print('tail = head + wsamples:\t', tail, '=', head, '+', wsamples)
            if print_out: print('still_tests:\t', trailing_tests)
            
            if sum(trailing_tests) == len(trailing_tests):
                if print_out: print('\tcoarse range found:\t', head, tail)
                refinedHead = None
                refinedTail = None
                for k in range(search - j):
                    # fine search every idx
                    fine_leading_head = head - fine_mult * (k + 1)
                    fine_leading_tail = tail - fine_mult * (k + 1)
                    fine_trailing_head = head + fine_mult * (k + 1)
                    fine_trailing_tail = tail + fine_mult * (k + 1)

                    if print_out: print('\tk iter:\t', k)
                    if print_out: print('\tfine_leading_head = head - fine_mult * k + 1:\t', fine_leading_head, '=', head, '-', fine_mult, '*', (k + 1))
                    if print_out: print('\tfine_leading_tail = tail - fine_mult * k + 1:\t', fine_leading_tail, '=', tail, '-', fine_mult, '*', (k + 1))
                    if print_out: print('\tfine_trailing_head = head + fine_mult * k + 1:\t', fine_trailing_head, '=', head, '+', fine_mult, '*', (k + 1))
                    if print_out: print('\tfine_trailing_tail = tail + fine_mult * k + 1:\t', fine_trailing_tail, '=', tail, '+', fine_mult, '*', (k + 1))

                    if refinedHead is None:
                        if fine_leading_head <= 0:
                            refinedHead = 0
                            print('\t\trefined head set:\t', refinedHead)
                        
                        leading_tests = testMotionForStillness(tile, [fine_leading_head, fine_leading_tail])
                        if print_out: print('\tleading_tests:\t', leading_tests)

                        if sum(leading_tests) < len(leading_tests):
                            refinedHead = fine_leading_head + fine_mult
                            print('\t\trefined head set:\t', refinedHead)

                    if refinedTail is None:
                        if fine_trailing_tail >= search:
                            refinedTail = fine_trailing_tail
                            print('\t\trefined tail set:\t', refinedTail)

                        trailing_tests = testMotionForStillness(tile, [fine_trailing_head, fine_trailing_tail])
                        if print_out: print('\ttrailing_tests:\t', trailing_tests)

                        if sum(trailing_tests) < len(trailing_tests):
                            refinedTail = fine_trailing_tail - fine_mult
                            if print_out: print('\t\trefined tail set:\t', refinedTail)

                    if refinedHead is not None and refinedTail is not None:
                        if refinedHead <= prev_tail:
                            if print_out: print('\t\tstitched to previous set:\t', [still_ranges[-1][0], refinedTail])
                            still_ranges[-1] = [still_ranges[-1][0], refinedTail]
                        else:
                            if print_out: print('\t\trefined still range set:\t', [refinedHead, refinedTail])
                            still_ranges.append([refinedHead, refinedTail])
                        prev_tail = refinedTail
                        break
                break

# %%
r = [0, len(tile_2023_12_30.time)]
# still_ranges = identifyStillRanges(tile_2023_12_30, r=r, print_out=True)

# %%
# print(len(still_ranges), "still points:", still_ranges)

# %%
def addStillZones(ax, t, ranges, r):
    for range in ranges:
        if range[0] < r[0] or range[1] > r[1]: 
            continue
        ax.axvspan(t[range[0]], t[range[1]], color='green', alpha=0.25)

# %%
def plotTileWithStillZones(tile, still_ranges, r=r):
    tile_euler6 = tile.imu6.euler
    tile_euler9 = tile.imu9.euler
    plt.rc('lines', linewidth=1)
    fig, ax = plt.subplots(6, figsize=(15, 10))

    ax[0].plot(tile.time[r[0]:r[1]], tile.corrected_alt[r[0]:r[1]])
    addStillZones(ax[0], tile.time, still_ranges, r)
    ax[0].set_title('All Tile Altitude with Still Zones', wrap=True)

    ax[1].plot(tile.time[r[0]:r[1]], tile_euler6[r[0]:r[1], 0], label='6dof')
    ax[1].plot(tile.time[r[0]:r[1]], tile_euler9[r[0]:r[1], 0], label='9dof')
    addStillZones(ax[1], tile.time, still_ranges, r)
    ax[1].set_title('All Tile Roll with Still Zones', wrap=True)
    ax[1].legend()

    ax[2].plot(tile.time[r[0]:r[1]], tile_euler6[r[0]:r[1], 1], label='6dof')
    ax[2].plot(tile.time[r[0]:r[1]], tile_euler9[r[0]:r[1], 1], label='9dof')
    addStillZones(ax[2], tile.time, still_ranges, r)
    ax[2].set_title('All Tile Pitch with Still Zones', wrap=True)
    ax[2].legend()

    ax[3].plot(tile.time[r[0]:r[1]], tile_euler6[r[0]:r[1], 2], label='6dof')
    ax[3].plot(tile.time[r[0]:r[1]], tile_euler9[r[0]:r[1], 2], label='9dof')
    addStillZones(ax[3], tile.time, still_ranges, r)
    ax[3].set_title('All Tile Yaw with Still Zones', wrap=True)
    ax[3].legend()

    ax[4].plot(tile.time[r[0]:r[1]], tile.mG_lpf()[r[0]:r[1]])
    addStillZones(ax[4], tile.time, still_ranges, r)
    ax[4].set_title('All Tile Filtered mG-forces with Still Zones', wrap=True)

    ax[5].plot(tile.time[r[0]:r[1]], tile.mG[r[0]:r[1]])
    addStillZones(ax[5], tile.time, still_ranges, r)
    ax[5].set_title('All Tile Unfiltered mG-forces with Still Zones', wrap=True)

    plt.tight_layout()
    plt.show()

# %%
# plotTileWithStillZones(tile_2023_12_30)
# print('Max alt occurs at:', tile_2023_12_30.corrected_alt.index(max(tile_2023_12_30.corrected_alt[90000:100000])))
# plotTileWithStillZones(tile_2023_12_30, still_ranges, [90000, 100000])
# print('Max alt occurs at:', tile_2023_12_30.corrected_alt.index(max(tile_2023_12_30.corrected_alt[150000:160000])))
# plotTileWithStillZones(tile_2023_12_30, still_ranges, [150000, 175000])

# %% [markdown]
# #### Check for Peak Altitude before `still_range`
#
# - search back from `head` until `prev_tail` for an impulse(s) in mG and max in alt
#   - confirm the alt at the current `head` is lower
# - in a much larger range, confirm the the previous max alt seen before current `head` and `prev_tail` has been the max for a while
#   - the "moving" max, account for lift stops

# %%
from stat_tests import StatTests as ST

def testContainsLocalPeak(x, r, print_out=False, header=""):
    """tests the input `x` signal for a peak inside the range `r`, excluding the endponits.
    
    if so, returns `True` else `False`
    """
    window, isValid = ST.assertWindow(x, r)
    if not isValid:
        return False

    max_window = max(window)
    head = x[r[0]]
    tail = x[r[1]]
    if print_out: print('\t', head, ' < ', max_window, ' < ', tail, '?', sep='')
    if head < max_window and max_window > tail:
        return True
    return False


def testLargeImpulse(x, r, th=None, print_out=False, header=""):
    """tests the input `x` signal whether a large impulse occured during the range `r`.
    
    `th` will override the threshold of the impulse magnitude test, defaults to 3 * stddev
    """
    window, isValid = ST.assertWindow(x, r)
    if not isValid:
        return False
    
    baseline = 3 * std(window) if th is None else th
    impulse = max(window)
    if print_out: print('\t', impulse, ' > ', baseline, '?', sep='')
    if impulse > baseline:
        return True
    return False

# %%
# # create IC
# prev_tail = 0

# for still_range in still_ranges:
#     testing_range = [prev_tail, still_range[0]]
#     print(testing_range)

#     if testContainsLocalPeak(tile_2023_12_30.corrected_alt, testing_range, print_out=True):
#         print('\tcontains alt peak?', True)
#     else:
#         print('\tcontains alt peak?', False)

#     if testLargeImpulse(tile_2023_12_30.corrected_alt, testing_range, th=2+tile_2023_12_30.corrected_alt[testing_range[1]], print_out=True):
#         print('\tcontains alt impulse?', True)
#     else:
#         print('\tcontains alt impulse?', False)

#     if testLargeImpulse(tile_2023_12_30.mG, testing_range, print_out=True):
#         print('\tcontains mG impulse?', True)
#     else:
#         print('\tcontains mG impulse?', False)

#     # update the tail for the next search
#     prev_tail = still_range[1]

# %% [markdown]
# ### V2
#
# 0. run is triggered by parent device, store idx
# 1. search left from this point for the first max in alt
# 2. find the first still point after this max and before the lift start
# 3. use the avg inside this still point as the platform zone

# %%
# run1_tile_start_idx = tile_2023_12_30.time.index(a50_2023_12_30[0].time[0])
# print(run1_tile_start_idx)
# run2_tile_start_idx = tile_2023_12_30.time.index(a50_2023_12_30[1].time[0])
# print(run2_tile_start_idx)

# %%
def findFirstHistoricMax(x, end, th=2):
    x1 = 0
    for i in range(len(x[0:end])):
        if x[end - i] - x[end - (i + 1)] > th:
            x1 = end - (i + 1)
            break
    return maxIndex(x, [x1, end])

# %%
# liftoff1_tile_idx = findFirstHistoricMax(tile_2023_12_30.corrected_alt, run1_tile_start_idx)
# print(liftoff1_tile_idx)
# liftoff2_tile_idx = findFirstHistoricMax(tile_2023_12_30.corrected_alt, run2_tile_start_idx)
# print(liftoff2_tile_idx)

# %%
# platform1_range = identifyStillRanges(tile_2023_12_30, r=[liftoff1_tile_idx, run1_tile_start_idx], min_s=1, print_out=True)
# print('\n\nNumber of still ranges found:', len(platform1_range))

# %% [markdown]
# The `run1_tile_start_idx` isn't reliable and requires feedback from parent, non ideal...

# %% [markdown]
# ### V3
#
# 0. Poll altitude at the start of a lift track
# 1. record when it starts decreasing past a certain threshold
# 2. wait for the first still point after this alt peak to define the platform zone
# 3. use the avg inside the platform zone

# %%
def getLiftPeakIdx(x, window_s=3*60, th=5, within_s=60):
    """Causal!
    
    Returns the index on input signal `x` where a max altitude is reached based on a
    drop detection within a certain period `within_s` seconds and threshold `th`.
    
    Confirms that this is a max over the last period `window_s` seconds."""
    fs = 100
    for i in range(len(x)):
        if i < window_s * fs:
            continue
        if x[i - (within_s * fs)] - x[i] > th and x[i - (within_s * fs)] == max(x[i - (window_s * fs):i]):
            return i - (within_s * fs)

# %%
max_lift1 = getLiftPeakIdx(tile_2023_12_30.corrected_alt)
max_lift2 = 100000 + getLiftPeakIdx(tile_2023_12_30.corrected_alt[100000:]) # represented as real-time

# %%
# wait for still point
# TODO write a more causal based algorithm to identify a rolling window, right now make an arbitrary window of + 10000 idx (10s)
platform1_ranges = identifyStillRanges(tile_2023_12_30, r=[max_lift1, max_lift1+10000], min_s=5, print_out=True)
platform2_ranges = identifyStillRanges(tile_2023_12_30, r=[max_lift2, max_lift2+10000], min_s=5, print_out=True)

platform1_lengths = [p[1] - p[0] for p in platform1_ranges]
still_idx_platform1 = maxIndex(platform1_lengths)
platform2_lengths = [p[1] - p[0] for p in platform2_ranges]
still_idx_platform2 = maxIndex(platform2_lengths)

print(still_idx_platform1)
print(still_idx_platform2)

platform1_range = platform1_ranges[still_idx_platform1]
platform2_range = platform2_ranges[still_idx_platform2]
# Out:
# search: 9500
# coarse_mult: 500
# fine_mult: 50
# i iter:	 0
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 91983 = 91983 + 0
# tail = head + wsamples:	 92483 = 91983 + 500
# still_tests:	 [False, False]
# j iter:	 1
# head = prev_tail + coarse_mult * j:	 92483 = 91983 + 500
# tail = head + wsamples:	 92983 = 92483 + 500
# still_tests:	 [False, False]
# j iter:	 2
# head = prev_tail + coarse_mult * j:	 92983 = 91983 + 1000
# tail = head + wsamples:	 93483 = 92983 + 500
# still_tests:	 [False, False]
# j iter:	 3
# head = prev_tail + coarse_mult * j:	 93483 = 91983 + 1500
# tail = head + wsamples:	 93983 = 93483 + 500
# still_tests:	 [False, False]
# j iter:	 4
# head = prev_tail + coarse_mult * j:	 93983 = 91983 + 2000
# tail = head + wsamples:	 94483 = 93983 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 93983 94483
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 93933 = 93983 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94433 = 94483 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 94033 = 93983 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 94533 = 94483 + 50 * 1
# 	leading_tests:	 [True, True]
# 		refined tail set:	 94533
# 	trailing_tests:	 [True, True]
# 	k iter:	 1
# 	fine_leading_head = head - fine_mult * k + 1:	 93883 = 93983 - 50 * 2
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94383 = 94483 - 50 * 2
# 	fine_trailing_head = head + fine_mult * k + 1:	 94083 = 93983 + 50 * 2
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 94583 = 94483 + 50 * 2
# 	leading_tests:	 [False, False]
# 		refined head set:	 93933
# 		refined still range set:	 [93933, 94533]
# i iter:	 1
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 94533 = 94533 + 0
# tail = head + wsamples:	 95033 = 94533 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 94533 95033
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 94483 = 94533 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94983 = 95033 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 94583 = 94533 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95083 = 95033 + 50 * 1
# 	leading_tests:	 [True, True]
# 		refined tail set:	 95083
# 	trailing_tests:	 [True, True]
# 	k iter:	 1
# 	fine_leading_head = head - fine_mult * k + 1:	 94433 = 94533 - 50 * 2
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94933 = 95033 - 50 * 2
# 	fine_trailing_head = head + fine_mult * k + 1:	 94633 = 94533 + 50 * 2
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95133 = 95033 + 50 * 2
# 	leading_tests:	 [True, True]
# 	k iter:	 2
# 	fine_leading_head = head - fine_mult * k + 1:	 94383 = 94533 - 50 * 3
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94883 = 95033 - 50 * 3
# 	fine_trailing_head = head + fine_mult * k + 1:	 94683 = 94533 + 50 * 3
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95183 = 95033 + 50 * 3
# 	leading_tests:	 [True, True]
# 	k iter:	 3
# 	fine_leading_head = head - fine_mult * k + 1:	 94333 = 94533 - 50 * 4
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94833 = 95033 - 50 * 4
# 	fine_trailing_head = head + fine_mult * k + 1:	 94733 = 94533 + 50 * 4
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95233 = 95033 + 50 * 4
# 	leading_tests:	 [True, True]
# 	k iter:	 4
# 	fine_leading_head = head - fine_mult * k + 1:	 94283 = 94533 - 50 * 5
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94783 = 95033 - 50 * 5
# 	fine_trailing_head = head + fine_mult * k + 1:	 94783 = 94533 + 50 * 5
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95283 = 95033 + 50 * 5
# 	leading_tests:	 [True, True]
# 	k iter:	 5
# 	fine_leading_head = head - fine_mult * k + 1:	 94233 = 94533 - 50 * 6
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94733 = 95033 - 50 * 6
# 	fine_trailing_head = head + fine_mult * k + 1:	 94833 = 94533 + 50 * 6
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95333 = 95033 + 50 * 6
# 	leading_tests:	 [True, True]
# 	k iter:	 6
# 	fine_leading_head = head - fine_mult * k + 1:	 94183 = 94533 - 50 * 7
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94683 = 95033 - 50 * 7
# 	fine_trailing_head = head + fine_mult * k + 1:	 94883 = 94533 + 50 * 7
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95383 = 95033 + 50 * 7
# 	leading_tests:	 [True, True]
# 	k iter:	 7
# 	fine_leading_head = head - fine_mult * k + 1:	 94133 = 94533 - 50 * 8
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94633 = 95033 - 50 * 8
# 	fine_trailing_head = head + fine_mult * k + 1:	 94933 = 94533 + 50 * 8
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95433 = 95033 + 50 * 8
# 	leading_tests:	 [True, True]
# 	k iter:	 8
# 	fine_leading_head = head - fine_mult * k + 1:	 94083 = 94533 - 50 * 9
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94583 = 95033 - 50 * 9
# 	fine_trailing_head = head + fine_mult * k + 1:	 94983 = 94533 + 50 * 9
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95483 = 95033 + 50 * 9
# 	leading_tests:	 [True, True]
# 	k iter:	 9
# 	fine_leading_head = head - fine_mult * k + 1:	 94033 = 94533 - 50 * 10
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94533 = 95033 - 50 * 10
# 	fine_trailing_head = head + fine_mult * k + 1:	 95033 = 94533 + 50 * 10
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95533 = 95033 + 50 * 10
# 	leading_tests:	 [True, True]
# 	k iter:	 10
# 	fine_leading_head = head - fine_mult * k + 1:	 93983 = 94533 - 50 * 11
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94483 = 95033 - 50 * 11
# 	fine_trailing_head = head + fine_mult * k + 1:	 95083 = 94533 + 50 * 11
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95583 = 95033 + 50 * 11
# 	leading_tests:	 [True, True]
# 	k iter:	 11
# 	fine_leading_head = head - fine_mult * k + 1:	 93933 = 94533 - 50 * 12
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94433 = 95033 - 50 * 12
# 	fine_trailing_head = head + fine_mult * k + 1:	 95133 = 94533 + 50 * 12
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95633 = 95033 + 50 * 12
# 	leading_tests:	 [True, True]
# 	k iter:	 12
# 	fine_leading_head = head - fine_mult * k + 1:	 93883 = 94533 - 50 * 13
# 	fine_leading_tail = tail - fine_mult * k + 1:	 94383 = 95033 - 50 * 13
# 	fine_trailing_head = head + fine_mult * k + 1:	 95183 = 94533 + 50 * 13
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 95683 = 95033 + 50 * 13
# 	leading_tests:	 [False, False]
# 		refined head set:	 93933
# 		stitched to previous set:	 [93933, 95083]
# i iter:	 2
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 95083 = 95083 + 0
# tail = head + wsamples:	 95583 = 95083 + 500
# still_tests:	 [False, False]
# j iter:	 1
# head = prev_tail + coarse_mult * j:	 95583 = 95083 + 500
# tail = head + wsamples:	 96083 = 95583 + 500
# still_tests:	 [False, False]
# j iter:	 2
# head = prev_tail + coarse_mult * j:	 96083 = 95083 + 1000
# tail = head + wsamples:	 96583 = 96083 + 500
# still_tests:	 [False, False]
# j iter:	 3
# head = prev_tail + coarse_mult * j:	 96583 = 95083 + 1500
# tail = head + wsamples:	 97083 = 96583 + 500
# still_tests:	 [False, False]
# j iter:	 4
# head = prev_tail + coarse_mult * j:	 97083 = 95083 + 2000
# tail = head + wsamples:	 97583 = 97083 + 500
# still_tests:	 [False, False]
# j iter:	 5
# head = prev_tail + coarse_mult * j:	 97583 = 95083 + 2500
# tail = head + wsamples:	 98083 = 97583 + 500
# still_tests:	 [False, False]
# j iter:	 6
# head = prev_tail + coarse_mult * j:	 98083 = 95083 + 3000
# tail = head + wsamples:	 98583 = 98083 + 500
# still_tests:	 [False, False]
# j iter:	 7
# head = prev_tail + coarse_mult * j:	 98583 = 95083 + 3500
# tail = head + wsamples:	 99083 = 98583 + 500
# still_tests:	 [False, False]
# j iter:	 8
# head = prev_tail + coarse_mult * j:	 99083 = 95083 + 4000
# tail = head + wsamples:	 99583 = 99083 + 500
# still_tests:	 [False, False]
# j iter:	 9
# head = prev_tail + coarse_mult * j:	 99583 = 95083 + 4500
# tail = head + wsamples:	 100083 = 99583 + 500
# still_tests:	 [False, False]
# j iter:	 10
# head = prev_tail + coarse_mult * j:	 100083 = 95083 + 5000
# tail = head + wsamples:	 100583 = 100083 + 500
# still_tests:	 [False, False]
# j iter:	 11
# head = prev_tail + coarse_mult * j:	 100583 = 95083 + 5500
# tail = head + wsamples:	 101083 = 100583 + 500
# still_tests:	 [False, False]
# hit the end of the line. tail >= search: 101583 >= 101483
# search: 9500
# coarse_mult: 500
# fine_mult: 50
# i iter:	 0
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 153949 = 153949 + 0
# tail = head + wsamples:	 154449 = 153949 + 500
# still_tests:	 [False, False]
# j iter:	 1
# head = prev_tail + coarse_mult * j:	 154449 = 153949 + 500
# tail = head + wsamples:	 154949 = 154449 + 500
# still_tests:	 [False, True]
# j iter:	 2
# head = prev_tail + coarse_mult * j:	 154949 = 153949 + 1000
# tail = head + wsamples:	 155449 = 154949 + 500
# still_tests:	 [False, False]
# j iter:	 3
# head = prev_tail + coarse_mult * j:	 155449 = 153949 + 1500
# tail = head + wsamples:	 155949 = 155449 + 500
# still_tests:	 [False, False]
# j iter:	 4
# head = prev_tail + coarse_mult * j:	 155949 = 153949 + 2000
# tail = head + wsamples:	 156449 = 155949 + 500
# still_tests:	 [False, False]
# j iter:	 5
# head = prev_tail + coarse_mult * j:	 156449 = 153949 + 2500
# tail = head + wsamples:	 156949 = 156449 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 156449 156949
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 156399 = 156449 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156899 = 156949 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 156499 = 156449 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 156999 = 156949 + 50 * 1
# 	leading_tests:	 [True, True]
# 		refined tail set:	 156999
# 	trailing_tests:	 [True, True]
# 	k iter:	 1
# 	fine_leading_head = head - fine_mult * k + 1:	 156349 = 156449 - 50 * 2
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156849 = 156949 - 50 * 2
# 	fine_trailing_head = head + fine_mult * k + 1:	 156549 = 156449 + 50 * 2
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157049 = 156949 + 50 * 2
# 	leading_tests:	 [True, True]
# 	k iter:	 2
# 	fine_leading_head = head - fine_mult * k + 1:	 156299 = 156449 - 50 * 3
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156799 = 156949 - 50 * 3
# 	fine_trailing_head = head + fine_mult * k + 1:	 156599 = 156449 + 50 * 3
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157099 = 156949 + 50 * 3
# 	leading_tests:	 [True, True]
# 	k iter:	 3
# 	fine_leading_head = head - fine_mult * k + 1:	 156249 = 156449 - 50 * 4
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156749 = 156949 - 50 * 4
# 	fine_trailing_head = head + fine_mult * k + 1:	 156649 = 156449 + 50 * 4
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157149 = 156949 + 50 * 4
# 	leading_tests:	 [True, True]
# 	k iter:	 4
# 	fine_leading_head = head - fine_mult * k + 1:	 156199 = 156449 - 50 * 5
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156699 = 156949 - 50 * 5
# 	fine_trailing_head = head + fine_mult * k + 1:	 156699 = 156449 + 50 * 5
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157199 = 156949 + 50 * 5
# 	leading_tests:	 [False, False]
# 		refined head set:	 156249
# 		refined still range set:	 [156249, 156999]
# i iter:	 1
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 156999 = 156999 + 0
# tail = head + wsamples:	 157499 = 156999 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 156999 157499
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 156949 = 156999 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157449 = 157499 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 157049 = 156999 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157549 = 157499 + 50 * 1
# 	leading_tests:	 [True, True]
# 		refined tail set:	 157549
# 	trailing_tests:	 [True, True]
# 	k iter:	 1
# 	fine_leading_head = head - fine_mult * k + 1:	 156899 = 156999 - 50 * 2
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157399 = 157499 - 50 * 2
# 	fine_trailing_head = head + fine_mult * k + 1:	 157099 = 156999 + 50 * 2
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157599 = 157499 + 50 * 2
# 	leading_tests:	 [True, True]
# 	k iter:	 2
# 	fine_leading_head = head - fine_mult * k + 1:	 156849 = 156999 - 50 * 3
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157349 = 157499 - 50 * 3
# 	fine_trailing_head = head + fine_mult * k + 1:	 157149 = 156999 + 50 * 3
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157649 = 157499 + 50 * 3
# 	leading_tests:	 [True, True]
# 	k iter:	 3
# 	fine_leading_head = head - fine_mult * k + 1:	 156799 = 156999 - 50 * 4
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157299 = 157499 - 50 * 4
# 	fine_trailing_head = head + fine_mult * k + 1:	 157199 = 156999 + 50 * 4
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157699 = 157499 + 50 * 4
# 	leading_tests:	 [True, True]
# 	k iter:	 4
# 	fine_leading_head = head - fine_mult * k + 1:	 156749 = 156999 - 50 * 5
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157249 = 157499 - 50 * 5
# 	fine_trailing_head = head + fine_mult * k + 1:	 157249 = 156999 + 50 * 5
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157749 = 157499 + 50 * 5
# 	leading_tests:	 [True, True]
# 	k iter:	 5
# 	fine_leading_head = head - fine_mult * k + 1:	 156699 = 156999 - 50 * 6
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157199 = 157499 - 50 * 6
# 	fine_trailing_head = head + fine_mult * k + 1:	 157299 = 156999 + 50 * 6
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157799 = 157499 + 50 * 6
# 	leading_tests:	 [True, True]
# 	k iter:	 6
# 	fine_leading_head = head - fine_mult * k + 1:	 156649 = 156999 - 50 * 7
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157149 = 157499 - 50 * 7
# 	fine_trailing_head = head + fine_mult * k + 1:	 157349 = 156999 + 50 * 7
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157849 = 157499 + 50 * 7
# 	leading_tests:	 [True, True]
# 	k iter:	 7
# 	fine_leading_head = head - fine_mult * k + 1:	 156599 = 156999 - 50 * 8
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157099 = 157499 - 50 * 8
# 	fine_trailing_head = head + fine_mult * k + 1:	 157399 = 156999 + 50 * 8
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157899 = 157499 + 50 * 8
# 	leading_tests:	 [True, True]
# 	k iter:	 8
# 	fine_leading_head = head - fine_mult * k + 1:	 156549 = 156999 - 50 * 9
# 	fine_leading_tail = tail - fine_mult * k + 1:	 157049 = 157499 - 50 * 9
# 	fine_trailing_head = head + fine_mult * k + 1:	 157449 = 156999 + 50 * 9
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157949 = 157499 + 50 * 9
# 	leading_tests:	 [True, True]
# 	k iter:	 9
# 	fine_leading_head = head - fine_mult * k + 1:	 156499 = 156999 - 50 * 10
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156999 = 157499 - 50 * 10
# 	fine_trailing_head = head + fine_mult * k + 1:	 157499 = 156999 + 50 * 10
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 157999 = 157499 + 50 * 10
# 	leading_tests:	 [True, True]
# 	k iter:	 10
# 	fine_leading_head = head - fine_mult * k + 1:	 156449 = 156999 - 50 * 11
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156949 = 157499 - 50 * 11
# 	fine_trailing_head = head + fine_mult * k + 1:	 157549 = 156999 + 50 * 11
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158049 = 157499 + 50 * 11
# 	leading_tests:	 [True, True]
# 	k iter:	 11
# 	fine_leading_head = head - fine_mult * k + 1:	 156399 = 156999 - 50 * 12
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156899 = 157499 - 50 * 12
# 	fine_trailing_head = head + fine_mult * k + 1:	 157599 = 156999 + 50 * 12
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158099 = 157499 + 50 * 12
# 	leading_tests:	 [True, True]
# 	k iter:	 12
# 	fine_leading_head = head - fine_mult * k + 1:	 156349 = 156999 - 50 * 13
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156849 = 157499 - 50 * 13
# 	fine_trailing_head = head + fine_mult * k + 1:	 157649 = 156999 + 50 * 13
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158149 = 157499 + 50 * 13
# 	leading_tests:	 [True, True]
# 	k iter:	 13
# 	fine_leading_head = head - fine_mult * k + 1:	 156299 = 156999 - 50 * 14
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156799 = 157499 - 50 * 14
# 	fine_trailing_head = head + fine_mult * k + 1:	 157699 = 156999 + 50 * 14
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158199 = 157499 + 50 * 14
# 	leading_tests:	 [True, True]
# 	k iter:	 14
# 	fine_leading_head = head - fine_mult * k + 1:	 156249 = 156999 - 50 * 15
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156749 = 157499 - 50 * 15
# 	fine_trailing_head = head + fine_mult * k + 1:	 157749 = 156999 + 50 * 15
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158249 = 157499 + 50 * 15
# 	leading_tests:	 [True, True]
# 	k iter:	 15
# 	fine_leading_head = head - fine_mult * k + 1:	 156199 = 156999 - 50 * 16
# 	fine_leading_tail = tail - fine_mult * k + 1:	 156699 = 157499 - 50 * 16
# 	fine_trailing_head = head + fine_mult * k + 1:	 157799 = 156999 + 50 * 16
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158299 = 157499 + 50 * 16
# 	leading_tests:	 [False, False]
# 		refined head set:	 156249
# 		stitched to previous set:	 [156249, 157549]
# i iter:	 2
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 157549 = 157549 + 0
# tail = head + wsamples:	 158049 = 157549 + 500
# still_tests:	 [False, True]
# j iter:	 1
# head = prev_tail + coarse_mult * j:	 158049 = 157549 + 500
# tail = head + wsamples:	 158549 = 158049 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 158049 158549
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 157999 = 158049 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158499 = 158549 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 158099 = 158049 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158599 = 158549 + 50 * 1
# 	leading_tests:	 [True, True]
# 		refined tail set:	 158599
# 	trailing_tests:	 [True, True]
# 	k iter:	 1
# 	fine_leading_head = head - fine_mult * k + 1:	 157949 = 158049 - 50 * 2
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158449 = 158549 - 50 * 2
# 	fine_trailing_head = head + fine_mult * k + 1:	 158149 = 158049 + 50 * 2
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158649 = 158549 + 50 * 2
# 	leading_tests:	 [True, True]
# 	k iter:	 2
# 	fine_leading_head = head - fine_mult * k + 1:	 157899 = 158049 - 50 * 3
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158399 = 158549 - 50 * 3
# 	fine_trailing_head = head + fine_mult * k + 1:	 158199 = 158049 + 50 * 3
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158699 = 158549 + 50 * 3
# 	leading_tests:	 [True, True]
# 	k iter:	 3
# 	fine_leading_head = head - fine_mult * k + 1:	 157849 = 158049 - 50 * 4
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158349 = 158549 - 50 * 4
# 	fine_trailing_head = head + fine_mult * k + 1:	 158249 = 158049 + 50 * 4
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 158749 = 158549 + 50 * 4
# 	leading_tests:	 [False, True]
# 		refined head set:	 157899
# 		refined still range set:	 [157899, 158599]
# i iter:	 3
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 158599 = 158599 + 0
# tail = head + wsamples:	 159099 = 158599 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 158599 159099
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 158549 = 158599 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159049 = 159099 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 158649 = 158599 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159149 = 159099 + 50 * 1
# 	leading_tests:	 [True, True]
# 		refined tail set:	 159149
# 	trailing_tests:	 [True, True]
# 	k iter:	 1
# 	fine_leading_head = head - fine_mult * k + 1:	 158499 = 158599 - 50 * 2
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158999 = 159099 - 50 * 2
# 	fine_trailing_head = head + fine_mult * k + 1:	 158699 = 158599 + 50 * 2
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159199 = 159099 + 50 * 2
# 	leading_tests:	 [True, True]
# 	k iter:	 2
# 	fine_leading_head = head - fine_mult * k + 1:	 158449 = 158599 - 50 * 3
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158949 = 159099 - 50 * 3
# 	fine_trailing_head = head + fine_mult * k + 1:	 158749 = 158599 + 50 * 3
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159249 = 159099 + 50 * 3
# 	leading_tests:	 [True, True]
# 	k iter:	 3
# 	fine_leading_head = head - fine_mult * k + 1:	 158399 = 158599 - 50 * 4
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158899 = 159099 - 50 * 4
# 	fine_trailing_head = head + fine_mult * k + 1:	 158799 = 158599 + 50 * 4
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159299 = 159099 + 50 * 4
# 	leading_tests:	 [True, True]
# 	k iter:	 4
# 	fine_leading_head = head - fine_mult * k + 1:	 158349 = 158599 - 50 * 5
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158849 = 159099 - 50 * 5
# 	fine_trailing_head = head + fine_mult * k + 1:	 158849 = 158599 + 50 * 5
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159349 = 159099 + 50 * 5
# 	leading_tests:	 [True, True]
# 	k iter:	 5
# 	fine_leading_head = head - fine_mult * k + 1:	 158299 = 158599 - 50 * 6
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158799 = 159099 - 50 * 6
# 	fine_trailing_head = head + fine_mult * k + 1:	 158899 = 158599 + 50 * 6
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159399 = 159099 + 50 * 6
# 	leading_tests:	 [True, True]
# 	k iter:	 6
# 	fine_leading_head = head - fine_mult * k + 1:	 158249 = 158599 - 50 * 7
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158749 = 159099 - 50 * 7
# 	fine_trailing_head = head + fine_mult * k + 1:	 158949 = 158599 + 50 * 7
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159449 = 159099 + 50 * 7
# 	leading_tests:	 [True, True]
# 	k iter:	 7
# 	fine_leading_head = head - fine_mult * k + 1:	 158199 = 158599 - 50 * 8
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158699 = 159099 - 50 * 8
# 	fine_trailing_head = head + fine_mult * k + 1:	 158999 = 158599 + 50 * 8
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159499 = 159099 + 50 * 8
# 	leading_tests:	 [True, True]
# 	k iter:	 8
# 	fine_leading_head = head - fine_mult * k + 1:	 158149 = 158599 - 50 * 9
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158649 = 159099 - 50 * 9
# 	fine_trailing_head = head + fine_mult * k + 1:	 159049 = 158599 + 50 * 9
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159549 = 159099 + 50 * 9
# 	leading_tests:	 [True, True]
# 	k iter:	 9
# 	fine_leading_head = head - fine_mult * k + 1:	 158099 = 158599 - 50 * 10
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158599 = 159099 - 50 * 10
# 	fine_trailing_head = head + fine_mult * k + 1:	 159099 = 158599 + 50 * 10
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159599 = 159099 + 50 * 10
# 	leading_tests:	 [True, True]
# 	k iter:	 10
# 	fine_leading_head = head - fine_mult * k + 1:	 158049 = 158599 - 50 * 11
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158549 = 159099 - 50 * 11
# 	fine_trailing_head = head + fine_mult * k + 1:	 159149 = 158599 + 50 * 11
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159649 = 159099 + 50 * 11
# 	leading_tests:	 [True, True]
# 	k iter:	 11
# 	fine_leading_head = head - fine_mult * k + 1:	 157999 = 158599 - 50 * 12
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158499 = 159099 - 50 * 12
# 	fine_trailing_head = head + fine_mult * k + 1:	 159199 = 158599 + 50 * 12
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159699 = 159099 + 50 * 12
# 	leading_tests:	 [True, True]
# 	k iter:	 12
# 	fine_leading_head = head - fine_mult * k + 1:	 157949 = 158599 - 50 * 13
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158449 = 159099 - 50 * 13
# 	fine_trailing_head = head + fine_mult * k + 1:	 159249 = 158599 + 50 * 13
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159749 = 159099 + 50 * 13
# 	leading_tests:	 [True, True]
# 	k iter:	 13
# 	fine_leading_head = head - fine_mult * k + 1:	 157899 = 158599 - 50 * 14
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158399 = 159099 - 50 * 14
# 	fine_trailing_head = head + fine_mult * k + 1:	 159299 = 158599 + 50 * 14
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159799 = 159099 + 50 * 14
# 	leading_tests:	 [True, True]
# 	k iter:	 14
# 	fine_leading_head = head - fine_mult * k + 1:	 157849 = 158599 - 50 * 15
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158349 = 159099 - 50 * 15
# 	fine_trailing_head = head + fine_mult * k + 1:	 159349 = 158599 + 50 * 15
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159849 = 159099 + 50 * 15
# 	leading_tests:	 [False, True]
# 		refined head set:	 157899
# 		stitched to previous set:	 [157899, 159149]
# i iter:	 4
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 159149 = 159149 + 0
# tail = head + wsamples:	 159649 = 159149 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 159149 159649
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 159099 = 159149 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159599 = 159649 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 159199 = 159149 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159699 = 159649 + 50 * 1
# 	leading_tests:	 [True, True]
# 		refined tail set:	 159699
# 	trailing_tests:	 [True, True]
# 	k iter:	 1
# 	fine_leading_head = head - fine_mult * k + 1:	 159049 = 159149 - 50 * 2
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159549 = 159649 - 50 * 2
# 	fine_trailing_head = head + fine_mult * k + 1:	 159249 = 159149 + 50 * 2
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159749 = 159649 + 50 * 2
# 	leading_tests:	 [True, True]
# 	k iter:	 2
# 	fine_leading_head = head - fine_mult * k + 1:	 158999 = 159149 - 50 * 3
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159499 = 159649 - 50 * 3
# 	fine_trailing_head = head + fine_mult * k + 1:	 159299 = 159149 + 50 * 3
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159799 = 159649 + 50 * 3
# 	leading_tests:	 [True, True]
# 	k iter:	 3
# 	fine_leading_head = head - fine_mult * k + 1:	 158949 = 159149 - 50 * 4
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159449 = 159649 - 50 * 4
# 	fine_trailing_head = head + fine_mult * k + 1:	 159349 = 159149 + 50 * 4
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159849 = 159649 + 50 * 4
# 	leading_tests:	 [True, True]
# 	k iter:	 4
# 	fine_leading_head = head - fine_mult * k + 1:	 158899 = 159149 - 50 * 5
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159399 = 159649 - 50 * 5
# 	fine_trailing_head = head + fine_mult * k + 1:	 159399 = 159149 + 50 * 5
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159899 = 159649 + 50 * 5
# 	leading_tests:	 [True, True]
# 	k iter:	 5
# 	fine_leading_head = head - fine_mult * k + 1:	 158849 = 159149 - 50 * 6
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159349 = 159649 - 50 * 6
# 	fine_trailing_head = head + fine_mult * k + 1:	 159449 = 159149 + 50 * 6
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159949 = 159649 + 50 * 6
# 	leading_tests:	 [True, True]
# 	k iter:	 6
# 	fine_leading_head = head - fine_mult * k + 1:	 158799 = 159149 - 50 * 7
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159299 = 159649 - 50 * 7
# 	fine_trailing_head = head + fine_mult * k + 1:	 159499 = 159149 + 50 * 7
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 159999 = 159649 + 50 * 7
# 	leading_tests:	 [True, True]
# 	k iter:	 7
# 	fine_leading_head = head - fine_mult * k + 1:	 158749 = 159149 - 50 * 8
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159249 = 159649 - 50 * 8
# 	fine_trailing_head = head + fine_mult * k + 1:	 159549 = 159149 + 50 * 8
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160049 = 159649 + 50 * 8
# 	leading_tests:	 [True, True]
# 	k iter:	 8
# 	fine_leading_head = head - fine_mult * k + 1:	 158699 = 159149 - 50 * 9
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159199 = 159649 - 50 * 9
# 	fine_trailing_head = head + fine_mult * k + 1:	 159599 = 159149 + 50 * 9
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160099 = 159649 + 50 * 9
# 	leading_tests:	 [True, True]
# 	k iter:	 9
# 	fine_leading_head = head - fine_mult * k + 1:	 158649 = 159149 - 50 * 10
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159149 = 159649 - 50 * 10
# 	fine_trailing_head = head + fine_mult * k + 1:	 159649 = 159149 + 50 * 10
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160149 = 159649 + 50 * 10
# 	leading_tests:	 [True, True]
# 	k iter:	 10
# 	fine_leading_head = head - fine_mult * k + 1:	 158599 = 159149 - 50 * 11
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159099 = 159649 - 50 * 11
# 	fine_trailing_head = head + fine_mult * k + 1:	 159699 = 159149 + 50 * 11
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160199 = 159649 + 50 * 11
# 	leading_tests:	 [True, True]
# 	k iter:	 11
# 	fine_leading_head = head - fine_mult * k + 1:	 158549 = 159149 - 50 * 12
# 	fine_leading_tail = tail - fine_mult * k + 1:	 159049 = 159649 - 50 * 12
# 	fine_trailing_head = head + fine_mult * k + 1:	 159749 = 159149 + 50 * 12
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160249 = 159649 + 50 * 12
# 	leading_tests:	 [True, True]
# 	k iter:	 12
# 	fine_leading_head = head - fine_mult * k + 1:	 158499 = 159149 - 50 * 13
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158999 = 159649 - 50 * 13
# 	fine_trailing_head = head + fine_mult * k + 1:	 159799 = 159149 + 50 * 13
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160299 = 159649 + 50 * 13
# 	leading_tests:	 [True, True]
# 	k iter:	 13
# 	fine_leading_head = head - fine_mult * k + 1:	 158449 = 159149 - 50 * 14
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158949 = 159649 - 50 * 14
# 	fine_trailing_head = head + fine_mult * k + 1:	 159849 = 159149 + 50 * 14
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160349 = 159649 + 50 * 14
# 	leading_tests:	 [True, True]
# 	k iter:	 14
# 	fine_leading_head = head - fine_mult * k + 1:	 158399 = 159149 - 50 * 15
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158899 = 159649 - 50 * 15
# 	fine_trailing_head = head + fine_mult * k + 1:	 159899 = 159149 + 50 * 15
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160399 = 159649 + 50 * 15
# 	leading_tests:	 [True, True]
# 	k iter:	 15
# 	fine_leading_head = head - fine_mult * k + 1:	 158349 = 159149 - 50 * 16
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158849 = 159649 - 50 * 16
# 	fine_trailing_head = head + fine_mult * k + 1:	 159949 = 159149 + 50 * 16
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160449 = 159649 + 50 * 16
# 	leading_tests:	 [True, True]
# 	k iter:	 16
# 	fine_leading_head = head - fine_mult * k + 1:	 158299 = 159149 - 50 * 17
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158799 = 159649 - 50 * 17
# 	fine_trailing_head = head + fine_mult * k + 1:	 159999 = 159149 + 50 * 17
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160499 = 159649 + 50 * 17
# 	leading_tests:	 [True, True]
# 	k iter:	 17
# 	fine_leading_head = head - fine_mult * k + 1:	 158249 = 159149 - 50 * 18
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158749 = 159649 - 50 * 18
# 	fine_trailing_head = head + fine_mult * k + 1:	 160049 = 159149 + 50 * 18
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160549 = 159649 + 50 * 18
# 	leading_tests:	 [True, True]
# 	k iter:	 18
# 	fine_leading_head = head - fine_mult * k + 1:	 158199 = 159149 - 50 * 19
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158699 = 159649 - 50 * 19
# 	fine_trailing_head = head + fine_mult * k + 1:	 160099 = 159149 + 50 * 19
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160599 = 159649 + 50 * 19
# 	leading_tests:	 [True, True]
# 	k iter:	 19
# 	fine_leading_head = head - fine_mult * k + 1:	 158149 = 159149 - 50 * 20
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158649 = 159649 - 50 * 20
# 	fine_trailing_head = head + fine_mult * k + 1:	 160149 = 159149 + 50 * 20
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160649 = 159649 + 50 * 20
# 	leading_tests:	 [True, True]
# 	k iter:	 20
# 	fine_leading_head = head - fine_mult * k + 1:	 158099 = 159149 - 50 * 21
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158599 = 159649 - 50 * 21
# 	fine_trailing_head = head + fine_mult * k + 1:	 160199 = 159149 + 50 * 21
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160699 = 159649 + 50 * 21
# 	leading_tests:	 [True, True]
# 	k iter:	 21
# 	fine_leading_head = head - fine_mult * k + 1:	 158049 = 159149 - 50 * 22
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158549 = 159649 - 50 * 22
# 	fine_trailing_head = head + fine_mult * k + 1:	 160249 = 159149 + 50 * 22
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160749 = 159649 + 50 * 22
# 	leading_tests:	 [True, True]
# 	k iter:	 22
# 	fine_leading_head = head - fine_mult * k + 1:	 157999 = 159149 - 50 * 23
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158499 = 159649 - 50 * 23
# 	fine_trailing_head = head + fine_mult * k + 1:	 160299 = 159149 + 50 * 23
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160799 = 159649 + 50 * 23
# 	leading_tests:	 [True, True]
# 	k iter:	 23
# 	fine_leading_head = head - fine_mult * k + 1:	 157949 = 159149 - 50 * 24
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158449 = 159649 - 50 * 24
# 	fine_trailing_head = head + fine_mult * k + 1:	 160349 = 159149 + 50 * 24
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160849 = 159649 + 50 * 24
# 	leading_tests:	 [True, True]
# 	k iter:	 24
# 	fine_leading_head = head - fine_mult * k + 1:	 157899 = 159149 - 50 * 25
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158399 = 159649 - 50 * 25
# 	fine_trailing_head = head + fine_mult * k + 1:	 160399 = 159149 + 50 * 25
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160899 = 159649 + 50 * 25
# 	leading_tests:	 [True, True]
# 	k iter:	 25
# 	fine_leading_head = head - fine_mult * k + 1:	 157849 = 159149 - 50 * 26
# 	fine_leading_tail = tail - fine_mult * k + 1:	 158349 = 159649 - 50 * 26
# 	fine_trailing_head = head + fine_mult * k + 1:	 160449 = 159149 + 50 * 26
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160949 = 159649 + 50 * 26
# 	leading_tests:	 [False, True]
# 		refined head set:	 157899
# 		stitched to previous set:	 [157899, 159699]
# i iter:	 5
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 159699 = 159699 + 0
# tail = head + wsamples:	 160199 = 159699 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 159699 160199
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 159649 = 159699 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 160149 = 160199 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 159749 = 159699 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 160249 = 160199 + 50 * 1
# 	leading_tests:	 [False, True]
# 		refined head set:	 159699
# 		refined tail set:	 160249
# 	trailing_tests:	 [True, True]
# 		stitched to previous set:	 [157899, 160249]
# i iter:	 6
# j iter:	 0
# head = prev_tail + coarse_mult * j:	 160249 = 160249 + 0
# tail = head + wsamples:	 160749 = 160249 + 500
# still_tests:	 [False, True]
# j iter:	 1
# head = prev_tail + coarse_mult * j:	 160749 = 160249 + 500
# tail = head + wsamples:	 161249 = 160749 + 500
# still_tests:	 [False, True]
# j iter:	 2
# head = prev_tail + coarse_mult * j:	 161249 = 160249 + 1000
# tail = head + wsamples:	 161749 = 161249 + 500
# still_tests:	 [False, False]
# j iter:	 3
# head = prev_tail + coarse_mult * j:	 161749 = 160249 + 1500
# tail = head + wsamples:	 162249 = 161749 + 500
# still_tests:	 [False, False]
# j iter:	 4
# head = prev_tail + coarse_mult * j:	 162249 = 160249 + 2000
# tail = head + wsamples:	 162749 = 162249 + 500
# still_tests:	 [False, True]
# j iter:	 5
# head = prev_tail + coarse_mult * j:	 162749 = 160249 + 2500
# tail = head + wsamples:	 163249 = 162749 + 500
# still_tests:	 [True, True]
# 	coarse range found:	 162749 163249
# 	k iter:	 0
# 	fine_leading_head = head - fine_mult * k + 1:	 162699 = 162749 - 50 * 1
# 	fine_leading_tail = tail - fine_mult * k + 1:	 163199 = 163249 - 50 * 1
# 	fine_trailing_head = head + fine_mult * k + 1:	 162799 = 162749 + 50 * 1
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 163299 = 163249 + 50 * 1
# 	leading_tests:	 [True, True]
# 		refined tail set:	 163299
# 	trailing_tests:	 [True, True]
# 	k iter:	 1
# 	fine_leading_head = head - fine_mult * k + 1:	 162649 = 162749 - 50 * 2
# 	fine_leading_tail = tail - fine_mult * k + 1:	 163149 = 163249 - 50 * 2
# 	fine_trailing_head = head + fine_mult * k + 1:	 162849 = 162749 + 50 * 2
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 163349 = 163249 + 50 * 2
# 	leading_tests:	 [True, True]
# 	k iter:	 2
# 	fine_leading_head = head - fine_mult * k + 1:	 162599 = 162749 - 50 * 3
# 	fine_leading_tail = tail - fine_mult * k + 1:	 163099 = 163249 - 50 * 3
# 	fine_trailing_head = head + fine_mult * k + 1:	 162899 = 162749 + 50 * 3
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 163399 = 163249 + 50 * 3
# 	leading_tests:	 [True, True]
# 	k iter:	 3
# 	fine_leading_head = head - fine_mult * k + 1:	 162549 = 162749 - 50 * 4
# 	fine_leading_tail = tail - fine_mult * k + 1:	 163049 = 163249 - 50 * 4
# 	fine_trailing_head = head + fine_mult * k + 1:	 162949 = 162749 + 50 * 4
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 163449 = 163249 + 50 * 4
# 	leading_tests:	 [True, True]
# 	k iter:	 4
# 	fine_leading_head = head - fine_mult * k + 1:	 162499 = 162749 - 50 * 5
# 	fine_leading_tail = tail - fine_mult * k + 1:	 162999 = 163249 - 50 * 5
# 	fine_trailing_head = head + fine_mult * k + 1:	 162999 = 162749 + 50 * 5
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 163499 = 163249 + 50 * 5
# 	leading_tests:	 [True, True]
# 	k iter:	 5
# 	fine_leading_head = head - fine_mult * k + 1:	 162449 = 162749 - 50 * 6
# 	fine_leading_tail = tail - fine_mult * k + 1:	 162949 = 163249 - 50 * 6
# 	fine_trailing_head = head + fine_mult * k + 1:	 163049 = 162749 + 50 * 6
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 163549 = 163249 + 50 * 6
# 	leading_tests:	 [True, True]
# 	k iter:	 6
# 	fine_leading_head = head - fine_mult * k + 1:	 162399 = 162749 - 50 * 7
# 	fine_leading_tail = tail - fine_mult * k + 1:	 162899 = 163249 - 50 * 7
# 	fine_trailing_head = head + fine_mult * k + 1:	 163099 = 162749 + 50 * 7
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 163599 = 163249 + 50 * 7
# 	leading_tests:	 [True, True]
# 	k iter:	 7
# 	fine_leading_head = head - fine_mult * k + 1:	 162349 = 162749 - 50 * 8
# 	fine_leading_tail = tail - fine_mult * k + 1:	 162849 = 163249 - 50 * 8
# 	fine_trailing_head = head + fine_mult * k + 1:	 163149 = 162749 + 50 * 8
# 	fine_trailing_tail = tail + fine_mult * k + 1:	 163649 = 163249 + 50 * 8
# 	leading_tests:	 [False, True]
# 		refined head set:	 162399
# 		refined still range set:	 [162399, 163299]
# i iter:	 7
# hit the end of the line. tail >= search: 163799 >= 163449
# 0
# 1

# %% [markdown]
# ## Calculating the Rotation Matrix Based on the Still Range Averages

# %%
plotTileWithStillZones(tile_2023_12_30, still_ranges=[platform1_range, platform2_range])
plotTileWithStillZones(tile_2023_12_30, r=[90000, 100000], still_ranges=[platform1_range])
plotTileWithStillZones(tile_2023_12_30, r=[150000, 175000], still_ranges=[platform2_range])

# %%
from signal_processing import mean

print('From static boot angles of [0, 0, 0] for NWU:\n')

r1_avg_roll = mean(tile_2023_12_30.imu9.computeEuler(cts_yaw=False)[platform1_range[0]:platform1_range[1], 0].tolist())
r1_avg_pitch = mean(tile_2023_12_30.imu9.computeEuler(cts_yaw=False)[platform1_range[0]:platform1_range[1], 1].tolist())
r1_avg_yaw = mean(tile_2023_12_30.imu9.computeEuler(cts_yaw=False)[platform1_range[0]:platform1_range[1], 2].tolist())
print('Clamped rotation offsets from top of lift 1:')
print('\t', r1_avg_roll, r1_avg_pitch, r1_avg_yaw)

r2_avg_roll = mean(tile_2023_12_30.imu9.computeEuler(cts_yaw=False)[platform2_range[0]:platform2_range[1], 0].tolist())
r2_avg_pitch = mean(tile_2023_12_30.imu9.computeEuler(cts_yaw=False)[platform2_range[0]:platform2_range[1], 1].tolist())
r2_avg_yaw = mean(tile_2023_12_30.imu9.computeEuler(cts_yaw=False)[platform2_range[0]:platform2_range[1], 2].tolist())
print('Clamped rotation offsets from top of lift 2:')
print('\t', r2_avg_roll, r2_avg_pitch, r2_avg_yaw)
# Out:
# From static boot angles of [0, 0, 0] for NWU:
#
# Clamped rotation offsets from top of lift 1:
# 	 -105.42796914874305 57.63495513917579 84.69816821627185
# Clamped rotation offsets from top of lift 2:
# 	 -98.37720271444373 56.275265059169314 92.97134230492378

# %%
import numpy as np
import math

# https://www.zacobria.com/universal-robots-knowledge-base-tech-support-forum-hints-tips-cb2-cb3/index.php/python-code-example-of-converting-rpyeuler-angles-to-rotation-vectorangle-axis-for-universal-robots/
def eulerToRotMatrix(roll, pitch, yaw):
    """zyx cardan sequence"""
    yawMatrix = np.matrix([
    [math.cos(yaw), -math.sin(yaw), 0],
    [math.sin(yaw), math.cos(yaw), 0],
    [0, 0, 1]
    ])

    pitchMatrix = np.matrix([
    [math.cos(pitch), 0, math.sin(pitch)],
    [0, 1, 0],
    [-math.sin(pitch), 0, math.cos(pitch)]
    ])

    rollMatrix = np.matrix([
    [1, 0, 0],
    [0, math.cos(roll), -math.sin(roll)],
    [0, math.sin(roll), math.cos(roll)]
    ])

    return yawMatrix * pitchMatrix * rollMatrix

    # for robotics and position:

    # theta = math.acos(((R[0, 0] + R[1, 1] + R[2, 2]) - 1) / 2)
    # multi = 1 / (2 * math.sin(theta))

    # rx = multi * (R[2, 1] - R[1, 2]) * theta
    # ry = multi * (R[0, 2] - R[2, 0]) * theta
    # rz = multi * (R[1, 0] - R[0, 1]) * theta

    # return rx, ry, rz

# %%
R_SB_1 = eulerToRotMatrix(r1_avg_roll, r1_avg_pitch, r1_avg_yaw)
R_SB_2 = eulerToRotMatrix(r2_avg_roll, r2_avg_pitch, r2_avg_yaw)

print('R_SB_1:', R_SB_1)
print('\nR_SB_2:', R_SB_2)
# Out:
# R_SB_1: [[-0.46214943 -0.88595362 -0.03878261]
#  [ 0.05799326 -0.07383327  0.99558296]
#  [-0.88490377  0.45785897  0.08550134]]
#
# R_SB_2: [[ 0.27935054 -0.59222257 -0.75580137]
#  [-0.92144357  0.05600213 -0.38445483]
#  [ 0.27000931  0.80382597 -0.53005545]]

# %% [markdown]
# ### Use Quaternions for Rotations...
#
# Prefer an average quaternion, using a direct method that accounts for double crossovers:

# %%
# def avgQuat(quats, weights=None):
#     """Assumes equal weighting between all the quaternions, otherwise override `weights` list."""
#     ws = np.ones(len(quats)) if weights is None else weights
#     qavg = np.array([0., 0., 0., 0.])
#     quats_arr = [np.array([q.x, q.y, q.z, q.w]) for q in quats]
#     for i, quat in enumerate(quats_arr):
#         # ensure each quat is normalized
#         quat = quat / np.linalg.norm(quat)

#         # flip, account for double cross over
#         if i > 0 and quat.dot(quats_arr[0]) < 0.:
#             print('double cross over!')
#             ws[i] -= 1

#         qavg = np.add(qavg, quat * ws[i])
#     return qavg / np.linalg.norm(qavg)

def avgQuat(quats, weights=None):
    """Performs the calculation for the average quaternion, based on the range `r` provided.
    
    Assumes equal weighting between all the quaternions, otherwise override `weights` list.

    Returns
    -------
    Average orientation quaternion [w, x, y, z] over range `r`.
    """
    ws = np.ones(len(quats)) if weights is None else weights
    qavg = np.array([0., 0., 0., 0.])
    for i, quat in enumerate(quats):
        # ensure each quat is normalized
        quat = quat / np.linalg.norm(quat)

        # flip, account for double cross over
        if i > 0 and quat.dot(quats[0]) < 0.:
            print('double cross over!')
            ws[i] -= 1

        qavg = np.add(qavg, quat * ws[i])
    qavg /= np.linalg.norm(qavg)
    print(qavg)
    return qavg / np.linalg.norm(qavg)

# %%
import numpy.matlib as npm

# https://github.com/christophhagen/averaging-quaternions/blob/8e75707891d2ad2f1bdecc5dc7b9bdb81fa7935f/averageQuaternions.py#L66
def weightedAverageQuaternions(quats, weights=None):
    Q = quats # np.array([np.array([q.w, q.x, q.y, q.z]) for q in quats])
    w = np.ones(len(quats)) if weights is None else weights

    # Number of quaternions to average
    M = Q.shape[0]
    A = npm.zeros(shape=(4,4))
    weightSum = 0

    for i in range(0,M):
        q = Q[i,:]
        A = w[i] * np.outer(q,q) + A
        weightSum += w[i]

    # scale
    A = (1.0/weightSum) * A

    # compute eigenvalues and -vectors
    eigenValues, eigenVectors = np.linalg.eig(A)

    # Sort by largest eigenvalue
    eigenVectors = eigenVectors[:,eigenValues.argsort()[::-1]]

    # return the real part of the largest eigenvector (has only real part)
    return np.real(eigenVectors[:,0].A1)

# %%
from signal_processing import rmse

print('Simple Average:')
qSB_1 = avgQuat(tile_2023_12_30.imu9.quat[platform1_range[0]:platform1_range[1], :])
print('\tqSB_1 (x, y, z, w):', qSB_1)
qSB_2 = avgQuat(tile_2023_12_30.imu9.quat[platform2_range[0]:platform2_range[1], :]) * -1
print('\tqSB_2 (x, y, z, w):', qSB_2)
print('\tRMSE between runs:', rmse(qSB_1, qSB_2))

print('\nAccurate Average:')
qSB_1 = weightedAverageQuaternions(tile_2023_12_30.imu9.quat[platform1_range[0]:platform1_range[1], :])
print('\tqSB_1 (w, x, y, z):', qSB_1)
qSB_2 = weightedAverageQuaternions(tile_2023_12_30.imu9.quat[platform2_range[0]:platform2_range[1], :]) * -1
print('\tqSB_2 (w, x, y, z):', qSB_2)
print('\tRMSE between runs:', rmse(qSB_1, qSB_2))
# Out:
# Simple Average:
# [ 0.13405157 -0.71178737 -0.25373257  0.6410996 ]
# 	qSB_1 (x, y, z, w): [ 0.13405157 -0.71178737 -0.25373257  0.6410996 ]
# [-0.13809109  0.68314521  0.2721622  -0.663454  ]
# 	qSB_2 (x, y, z, w): [ 0.13809109 -0.68314521 -0.2721622   0.663454  ]
# 	RMSE between runs: 0.020469864936160327
#
# Accurate Average:
# 	qSB_1 (w, x, y, z): [-0.13405583  0.71178703  0.2537437  -0.64109469]
# 	qSB_2 (w, x, y, z): [-0.13814244  0.68314366  0.27213496 -0.66345608]
# 	RMSE between runs: 0.020465907502397216

# %% [markdown]
# `q` = `-q` represent the same rotation! It's addressed inside the function itself element-wise, but comparing outputs between runs may be the opposite signs.
