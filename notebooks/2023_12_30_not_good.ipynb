# %% [markdown]
# # December 30, 2023
#
# ## Notes
#
# - recording didn't pan out on the tile, stopped a couple runs in. Investigate why!
# - 22 runs
# - warmer day
# - busy
# - stuck to the main blue run beside the tri lift (now a quad) & the black that crosses under the other main quad main lift
# - group skiing with boo & isaac
#
# ### A50 Metadata
#
# SkiApp PRO 2.3.9 - Available in Google PlayStore
# 1. Skiing Track "Hold" @ Dec. 26, 2022, 10:47:46 a.m., Duration=1'58'', Length=43m
#
# #### Columns
#
# Time [Sec]
# Distance [m]
# Velocity [kmh]
# Course [°]
# Altitude [m]
# Latitude [°]
# Longitude [°]
# Accuracy [m]
#
# ### Fenix 6 Pro Metadata
#
# #### Columns
#
# "Runs",
# "Time",
# "Distance",
# "Total Descent",
# "Max Speed",
# "Avg Speed",
# "Avg Moving Speed",
# "Calories",
# "Avg HR",
# "Max HR",
# "Cumulative Time",
# "Moving Time",
# "Avg Temperature"
#
# ### SensorTile Box Metadata
#
# #### Columns
#
# T [ms],
# AccX [mg],
# AccY [mg],
# AccZ [mg],
# GyroX [mdps],
# GyroY [mdps],
# GyroZ [mdps],
# MagX [mgauss],
# MagY [mgauss],
# MagZ [mgauss],
# P [mB],
# T ['C],
# H [%]
