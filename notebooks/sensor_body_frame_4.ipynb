# %% [markdown]
# # Sensor Body Frame Registration 4 (cont'd)
#
# Testing the correct cardan sequence to accurately represent orientation from the quaternion.
#
# Default is `ZYX`, which works for

# %%
from sessions import Session_2024_02_08, Session_2024_02_09, Session_2024_02_09_Boot_Frame
from plotting import plotAllTileEulerAnalyses

session_2024_02_08 = Session_2024_02_08(prototype_sigs=True)
session_2024_02_09 = Session_2024_02_09(prototype_sigs=True)
session_2024_02_09_bf = Session_2024_02_09_Boot_Frame(prototype_sigs=True)

# %%
plotAllTileEulerAnalyses(session_2024_02_08.tile)

# %%
plotAllTileEulerAnalyses(session_2024_02_09.tile)

# %%
plotAllTileEulerAnalyses(session_2024_02_09_bf.tile)
