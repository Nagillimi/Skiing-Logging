# %% [markdown]
# # December 24, 2022
#
# ## Notes
#
# - Mt Morin Heights
# - not busy
# - snow slow, lots of powder
# - not many runs open

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
f35 = pd.read_csv("../DATA/2022_12_24/Mt Morin Heights/F35-left-wrist/activity_10181474438.csv")
a50 = pd.read_csv("../DATA/2022_12_24/Mt Morin Heights/A50-torso/Morning ski at Morin Heights.csv", header=2)

# parse into components, they're sorted by the activity in the same columns
print(f35.columns)
print(a50.columns)
# Out:
# Index(['Runs', 'Time', 'Distance', 'Total Descent', 'Max Speed', 'Avg Speed',
#        'Avg Moving Speed', 'Calories', 'Avg HR', 'Max HR', 'Cumulative Time',
#        'Moving Time', 'Avg Temperature'],
#       dtype='object')
# Index(['Time [Sec]', 'Distance [m]', 'Velocity [kmh]', 'Course [°]',
#        'Altitude [m]', 'Latitude [°]', 'Longitude [°]', 'Accuracy [m]'],
#       dtype='object')

# %%
# a50_run1 = a50.to_numpy()
print(a50[1384:1495, :])
# a50_run1.plot(x='Time [Sec]', y='Altitude [m]')
# Out:
#   Cell In[64], line 2
#     print(a50_run1([[1384:1495], [:]]))
#                          ^
# SyntaxError: invalid syntax

# %%
f35.plot()
# f35.plot(kind = 'scatter', x = 'Time', y = 'Max Speed')
# plt.show()
# Out:
# <Axes: >
