# %% [markdown]
# # Sensor Body Frame Registration 5 (cont'd)
#
# ## Stillness Detection Adjustment
#
# Final result, adjusted the still motion detection to only poll the mG-forces since the euler norm is incrediably non-performant.

# %%
from domain.sessions import Session_2023_12_30

session_2023_12_30 = Session_2023_12_30()

# %%
from utilities.plotting import plotAllTileRegistationZones

plotAllTileRegistationZones(session_2023_12_30.tile)

# %% [markdown]
# ## Final Boot Orientations!

# %%
from utilities.plotting import plotAllSensorBootEuler

plotAllSensorBootEuler(session_2023_12_30.tile)
