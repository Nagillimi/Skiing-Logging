# %% [markdown]
# # December 24, 2022
#
# ## Notes
#
# - Mt Olympia
# - felt great
# - not too busy
# - snow was semi-fast
#
# ### A50 Metadata
#
# SkiApp PRO 2.3.9 - Available in Google PlayStore
# 1. Skiing Track "Hold" @ Dec. 26, 2022, 10:47:46 a.m., Duration=1'58'', Length=43m
#
# #### Columns
#
# Time [Sec]
# Distance [m]
# Velocity [kmh]
# Course [°]
# Altitude [m]
# Latitude [°]
# Longitude [°]
# Accuracy [m]
#
# ### Forerunner 35 Metadata
#
# #### Columns
#
# "Runs",
# "Time",
# "Distance",
# "Total Descent",
# "Max Speed",
# "Avg Speed",
# "Avg Moving Speed",
# "Calories",
# "Avg HR",
# "Max HR",
# "Cumulative Time",
# "Moving Time",
# "Avg Temperature"
#
# ### SensorTile Box Metadata
#
# #### Columns
#
# T [ms],
# AccX [mg],
# AccY [mg],
# AccZ [mg],
# GyroX [mdps],
# GyroY [mdps],
# GyroZ [mdps],
# MagX [mgauss],
# MagY [mgauss],
# MagZ [mgauss],
# P [mB],
# T ['C],
# H [%]
