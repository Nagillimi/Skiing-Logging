# %% [markdown]
# # January 1, 2024
#
# ## Notes
#
# - Fast corderoy
# - coaching sarah for the first few runs
# - some bombing runs
# - the blue run beside the lift (sept-isles) was the best for carving
# - had to do a quick stop at the end of the last run
# - a few blind corners on the black run in general, led to some speed checking
# - group skiing with boo & isaac

# %%
from decode import decode_A50_downhill, decode_F6P, decode_tile
import pandas as pd

a50 = decode_A50_downhill("../DATA/2024_01_01/Mt Morin Heights/A50/Mount Morin Heights.csv")
f6p = decode_F6P("../DATA/2024_01_01/Mt Morin Heights/F6P/13319383173_ACTIVITY.csv")
tile = decode_tile("../DATA/2024_01_01/Mt Morin Heights/Tile/SENS000.CSV")

# %%
print(len(a50))
print(len(f6p))
# Out:
# 23
# 19

# %%
for a in a50:
    print(a.__printProps__())
# Out:
# Track type Downhill | Date 2024-01-01 | Time 12:39:48 | Duration [s] 43 | Length [m] 148
# None
# Track type Downhill | Date 2024-01-01 | Time 12:41:34 | Duration [s] 43 | Length [m] 104
# None
# Track type Downhill | Date 2024-01-01 | Time 12:45:23 | Duration [s] 105 | Length [m] 328
# None
# Track type Downhill | Date 2024-01-01 | Time 12:53:59 | Duration [s] 109 | Length [m] 589
# None
# Track type Downhill | Date 2024-01-01 | Time 13:00:49 | Duration [s] 42 | Length [m] 75
# None
# Track type Downhill | Date 2024-01-01 | Time 13:09:30 | Duration [s] 220 | Length [m] 1078
# None
# Track type Downhill | Date 2024-01-01 | Time 13:23:24 | Duration [s] 171 | Length [m] 830
# None
# Track type Downhill | Date 2024-01-01 | Time 13:34:45 | Duration [s] 97 | Length [m] 804
# None
# Track type Downhill | Date 2024-01-01 | Time 13:42:37 | Duration [s] 87 | Length [m] 759
# None
# Track type Downhill | Date 2024-01-01 | Time 13:49:47 | Duration [s] 96 | Length [m] 799
# None
# ...

# %%
for f in f6p:
    print(f.__printProps__())
# Out:
# Track type Downhill | Date 2024-01-01 | Time 12:38:15 | Duration [s] 163 | Length [m] 524.14
# None
# Track type Downhill | Date 2024-01-01 | Time 12:53:36 | Duration [s] 83 | Length [m] 552.08
# None
# Track type Downhill | Date 2024-01-01 | Time 13:09:37 | Duration [s] 179 | Length [m] 1008.53
# None
# Track type Downhill | Date 2024-01-01 | Time 13:23:45 | Duration [s] 75 | Length [m] 816.37
# None
# Track type Downhill | Date 2024-01-01 | Time 13:35:14 | Duration [s] 66 | Length [m] 733.53
# None
# Track type Downhill | Date 2024-01-01 | Time 13:42:42 | Duration [s] 68 | Length [m] 732.13
# None
# Track type Downhill | Date 2024-01-01 | Time 13:50:13 | Duration [s] 65 | Length [m] 736.42
# None
# Track type Downhill | Date 2024-01-01 | Time 13:57:57 | Duration [s] 66 | Length [m] 736.78
# None
# Track type Downhill | Date 2024-01-01 | Time 14:06:01 | Duration [s] 74 | Length [m] 780.98
# None
# ...

# %% [markdown]
# ## Confirm which ground truth is correct here!

# %%
from plotting import plot_a50_f6p

for i in range(len(a50)):
    print("Downhill track", i + 1)
    plot_a50_f6p(a50[i], f6p[i])
# Out:
# Downhill track 1
# Downhill track 2
# Downhill track 3
# Downhill track 4
# Downhill track 5
# Downhill track 6
# Downhill track 7
# Downhill track 8
# Downhill track 9
# Downhill track 10
# Downhill track 11
# Downhill track 12
# Downhill track 13
# Downhill track 14
# Downhill track 15
# Downhill track 16
# Downhill track 17
# Downhill track 18
# Downhill track 19
# Downhill track 20
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 5
#       3 for i in range(len(a50)):
#       4     print("Downhill track", i + 1)
# ----> 5     plot_a50_f6p(a50[i], f6p[i])
#
# IndexError: list index out of range
